# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("verticalized_products.xls - Sheet1.csv")

# %%
df.pivot_table(index='Product Name', columns='month')
# Out:
#                                                    Sales                    \
# month                                                Apr   Aug   Dec   Feb
# Product Name
# "While you Were Out" Message Book, One Form per...   976   939  1092   909
# #10 Gummed Flap White Envelopes, 100/Box            1121   922  1242  1167
# #10 Self-Seal White Envelopes                       1632  1574  1656  1477
# #10 White Business Envelopes,4 1/8 x 9 1/2          1132   959  1092  1244
# #10- 4 1/8" x 9 1/2" Recycled Envelopes              806   628   859   720
# ...                                                  ...   ...   ...   ...
# iKross Bluetooth Portable Keyboard + Cell Phone...   865   543   759   727
# iOttie HLCRIO102 Car Mount                           937   790  1026  1009
# iOttie XL Car Mount                                 1204  1050  1259  1085
# invisibleSHIELD by ZAGG Smudge-Free Screen Prot...   782   774   858   847
# ...

# %%
df2 = pd.read_excel("Sample - Superstore-2.xlsx")
df2.head(2)
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City  ... Postal Code  Region  \
# 0   Claire Gute  Consumer  United States  Henderson  ...       42420   South
# 1   Claire Gute  Consumer  United States  Henderson  ...       42420   South
#
#         Product ID   Category Sub-Category  \
# 0  FUR-BO-10001798  Furniture    Bookcases
# 1  FUR-CH-10000454  Furniture       Chairs
#
#                                         Product Name   Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3
#
#    Discount    Profit
# 0       0.0   41.9136
# 1       0.0  219.5820
#
# [2 rows x 21 columns]

# %%
df2.pivot_table(index= ['Category', 'Region',], values=['Sales'], aggfunc=np.sum)
# Out:
#                                Sales
# Category        Region
# Furniture       Central  163797.1638
#                 East     208291.2040
#                 South    117298.6840
#                 West     252612.7435
# Office Supplies Central  167026.4150
#                 East     205516.0550
#                 South    125651.3130
#                 West     220853.2490
# Technology      Central  170416.3120
#                 East     264973.9810
#                 South    148771.9080
#                 West     251991.8320

# %%
df2.pivot_table(
    index=["Region", "State"],
    columns="Category",
    values=["Sales", "Profit"],
    aggfunc=lambda x: np.max(x) - np.min(x),
    fill_value=0,
)
# Out:
#                                  Profit                                Sales  \
# Category                      Furniture Office Supplies Technology Furniture
# Region  State
# Central Illinois               566.5625       3076.2745   894.4575   911.538
#         Indiana                537.8787        793.7160  8399.0850  2676.030
#         Iowa                   389.6459         51.8528    57.5838  1393.190
#         Kansas                  11.0112        147.6540    63.9082    30.000
#         Michigan               698.6279       4946.3700   828.9374  3499.430
#         Minnesota              767.3952       4630.4755   273.1790  2561.680
#         Missouri               211.3446        754.8128  2300.6681  1014.700
#         Nebraska               380.5628        135.8784   743.6883  1320.520
#         North Dakota             0.0000        161.2268     0.0000     0.000
#         Oklahoma               510.6504        250.2015   373.8272  1775.520
# ...
