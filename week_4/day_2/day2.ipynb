# %%
import pandas as pd

# %%
df = pd.read_csv("verticalized_products.xls - Sheet1.csv")

# %%
df.pivot_table(values='Sales', index='Product Name', columns='month')
# Out:
# month                                                Apr   Aug   Dec   Feb  \
# Product Name
# "While you Were Out" Message Book, One Form per...   976   939  1092   909
# #10 Gummed Flap White Envelopes, 100/Box            1121   922  1242  1167
# #10 Self-Seal White Envelopes                       1632  1574  1656  1477
# #10 White Business Envelopes,4 1/8 x 9 1/2          1132   959  1092  1244
# #10- 4 1/8" x 9 1/2" Recycled Envelopes              806   628   859   720
# ...                                                  ...   ...   ...   ...
# iKross Bluetooth Portable Keyboard + Cell Phone...   865   543   759   727
# iOttie HLCRIO102 Car Mount                           937   790  1026  1009
# iOttie XL Car Mount                                 1204  1050  1259  1085
# invisibleSHIELD by ZAGG Smudge-Free Screen Prot...   782   774   858   847
# netTALK DUO VoIP Telephone Service                  1328  1030  1276  1212
#
# ...

# %%
df.pivot(index='Product Name', columns='month')
# Out:
#                                                    Sales                    \
# month                                                Apr   Aug   Dec   Feb
# Product Name
# "While you Were Out" Message Book, One Form per...   976   939  1092   909
# #10 Gummed Flap White Envelopes, 100/Box            1121   922  1242  1167
# #10 Self-Seal White Envelopes                       1632  1574  1656  1477
# #10 White Business Envelopes,4 1/8 x 9 1/2          1132   959  1092  1244
# #10- 4 1/8" x 9 1/2" Recycled Envelopes              806   628   859   720
# ...                                                  ...   ...   ...   ...
# iKross Bluetooth Portable Keyboard + Cell Phone...   865   543   759   727
# iOttie HLCRIO102 Car Mount                           937   790  1026  1009
# iOttie XL Car Mount                                 1204  1050  1259  1085
# invisibleSHIELD by ZAGG Smudge-Free Screen Prot...   782   774   858   847
# ...
