# %% [markdown]
# # - Challenge 1 , Quest 1

# %%
import requests
import pandas as pd
import json

# %%
url = 'https://api.github.com/repos/ironhack-datalabs/madrid-oct-2018'
headers = {'Authorization' : 'token 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'}
json = requests.get(url,headers=headers).json()

# %%
forks_url = json['forks_url']

# %% [markdown]
# # - Challenge 1 Quest 2

# %%
json2 = requests.get(forks_url, headers=headers).json()

# %%
l = set()
for fork in json2:
    l.add(fork['language'])
# Out:
# ['HTML', None, 'Jupyter Notebook']

# %% [markdown]
# # - Challenge 1 Quest 3

# %%
display(list(l))
# Out:
# ['HTML', None, 'Jupyter Notebook']

# %% [markdown]
# # - Challenge 2 Quest 1

# %%
url = 'https://api.github.com/repos/AdrianCarcelen/IronSirvine'
headers = {'Authorization' : 'token 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'}
json3 = requests.get(url,headers=headers).json()

# %%
json4 = requests.get(json3['commits_url'].replace('{/sha}',''),headers=headers).json()

# %%
json4
# Out:
# [{'sha': '370361e2bbbba6d3b45cdae6c0bb535a67f407bc',
#   'node_id': 'C_kwDOJ9N0i9oAKDM3MDM2MWUyYmJiYmE2ZDNiNDVjZGFlNmMwYmI1MzVhNjdmNDA3YmM',
#   'commit': {'author': {'name': 'AdrianCarcelen',
#     'email': 'adrian.carcelen@gmail.com',
#     'date': '2023-07-25T11:04:22Z'},
#    'committer': {'name': 'AdrianCarcelen',
#     'email': 'adrian.carcelen@gmail.com',
#     'date': '2023-07-25T11:04:22Z'},
#    'message': 'e',
#    'tree': {'sha': 'eb374859a5cf42745c00b5460f7e132bf3a2d9ca',
#     'url': 'https://api.github.com/repos/AdrianCarcelen/IronSirvine/git/trees/eb374859a5cf42745c00b5460f7e132bf3a2d9ca'},
#    'url': 'https://api.github.com/repos/AdrianCarcelen/IronSirvine/git/commits/370361e2bbbba6d3b45cdae6c0bb535a67f407bc',
#    'comment_count': 0,
#    'verification': {'verified': False,
#     'reason': 'unsigned',
#     'signature': None,
#     'payload': None}},
# ...

# %%
len(json4)
# Out:
# 30
